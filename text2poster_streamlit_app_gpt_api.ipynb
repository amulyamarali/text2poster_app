# %% [markdown]
# <a href="https://colab.research.google.com/github/amulyamarali/text2poster_app/blob/master/text2poster_streamlit_app_gpt_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**NOT THIS**

# %%
import streamlit as st
import os
import torch
from diffusers import StableDiffusionPipeline

# generate imae using stable difusion
def gen_img_SD(input_text):
    pipe = StableDiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5", torch_dtype = torch.float16)
    pipe = pipe.to("cuda")
    image = pipe(input_text).images[0]
    return image

st.title("Text2Poster AI")
input_text = st.text_input("Enter the product name")
if input_text is not None:
    if st.button("Generate Poster"):
        st.info(input_text)
        image = gen_img_SD(input_text)
        st.image(image)
# Out:
# 2023-06-11 06:16:42.634
# ...
#   command:
#
#     streamlit run /usr/local/lib/python3.10/dist-packages/ipykernel_launcher.py [ARGUMENTS]

# %%
# !streamlit run /content/app.py [ARGUMENTS] --server.port 8500
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8500
#   External URL: http://35.204.123.78:8500
#
#   Stopping...
#   Stopping...

# %%
# !pip install diffusers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 895.8/895.8 kB 30.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 22.7 MB/s eta 0:00:00
# ...
#   Created wheel for diffusers: filename=diffusers-0.18.1-py3-none-any.whl size=1247776 sha256=f0d8cbcd06b9fbf4beacbfa1fd17d59482a769a11591efb482ef4913f8797ea1
#   Stored in directory: /root/.cache/pip/wheels/24/a6/0f/76cc29c67a153b1a711662ce4181c8463815f1186336ba07ec
# Successfully built diffusers
# ...

# %%
# !pip install streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 63.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 kB 19.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 17.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 75.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 9.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 32.4 MB/s eta 0:00:00
# ...
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19579 sha256=a316d5642f1883effb59e9e6ff2139e8ef8e868a3c2d5df3b775cc7df34f89b9
#   Stored in directory: /root/.cache/pip/wheels/f2/ed/dd/d3a556ad245ef9dc570c6bcd2f22886d17b0b408dd3bbb9ac3
# Successfully built validators
# ...
#   Attempting uninstall: tzlocal
# ...

# %%
# !pip install transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 70.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 83.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 64.3 MB/s eta 0:00:00
# ...

# %%
import cv2
from diffusers import StableDiffusionPipeline
import transformers
import torch

input_text = "sports shoes"
pipe = StableDiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5", torch_dtype = torch.float16)
pipe = pipe.to("cuda")
image = pipe(input_text).images[0]
cv2.imshow(image)
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# ...
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# ...
# Cannot initialize model with low cpu memory usage because `accelerate` was not found in the environment. Defaulting to `low_cpu_mem_usage=False`. It is strongly recommended to install `accelerate` for faster and less memory-intense model loading. You can do so with:
# ```
# pip install accelerate
# ```
# .
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
#   0%|          | 0/50 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# DisabledFunctionError                     Traceback (most recent call last)
# ...

# %%
# !pip install diffusers==0.11.1
# !pip install transformers scipy ftfy accelerate

# %% [markdown]
# # **FROM HERE**

# %%
# !pip install diffusers==0.11.1
# !pip install transformers scipy ftfy accelerate
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 524.9/524.9 kB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 9.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 56.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 26.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 104.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 81.2 MB/s eta 0:00:00
# ...

# %%
import torch
from diffusers import StableDiffusionPipeline

pipe = StableDiffusionPipeline.from_pretrained("CompVis/stable-diffusion-v1-4", torch_dtype=torch.float16)
# Out:
# ...
# safety_checker/pytorch_model.fp16.safetensors not found
# Fetching 28 files:   0%|          | 0/28 [00:00<?, ?it/s]
# ...
# The config attributes {'scaling_factor': 0.18215} were passed to AutoencoderKL, but are not expected and will be ignored. Please verify your config.json configuration file.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["bos_token_id"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["eos_token_id"]` will be overriden.

# %%
pipe = pipe.to("cuda")

# %%
prompt = "sport shoes"
image = pipe(prompt).images[0]  # image here is in [PIL format](https://pillow.readthedocs.io/en/stable/)

# Now to display an image you can either save it such as:
image.save(f"a_1.png")

# or if you're in a google colab you can directly display it with
image
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
from PIL import Image, ImageFont, ImageDraw

# %%
my_image = Image.open("/content/a_1.png")

# %%
title_font = ImageFont.truetype("/content/Poppins-Medium.ttf",50)

# %%
title_text = "Right Now!"

# %%
image_editable = ImageDraw.Draw(my_image)

# %%
image_editable.text((15,15), title_text,(237,230,211), font = title_font)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-efef4602d995> in <cell line: 1>()
# ----> 1 image_editable.text((15,15), title_text,(237,230,211), font = title_font)
#
# NameError: name 'title_text' is not defined

# %%
my_image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x7F1E592FFC40>

# %%
import streamlit as st
import os
import torch
from diffusers import StableDiffusionPipeline

# generate imae using stable difusion
def gen_img_SD(input_text):
    pipe = StableDiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5", torch_dtype = torch.float16)
    pipe = pipe.to("cuda")
    image = pipe(input_text).images[0]
    return image

st.title("Text2Poster AI")
input_text = st.text_input("Enter the product name")
if input_text is not None:
    if st.button("Generate Poster"):
        st.info(input_text)
        image = gen_img_SD(input_text)
        st.image(image)
# Out:
# 2023-07-10 12:38:43.472
# ...
#   command:
#
#     streamlit run /usr/local/lib/python3.10/dist-packages/ipykernel_launcher.py [ARGUMENTS]

# %%
# !streamlit run /usr/local/lib/python3.10/dist-packages/ipykernel_launcher.py [ARGUMENTS] --server.port 8500
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8500
#   External URL: http://34.126.130.146:8500
#
#   Stopping...
#   Stopping...

# %%
# !streamlit run /content/app.py [ARGUMENTS] --server.port 8500
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8500
#   External URL: http://34.126.130.146:8500
#
#   Stopping...
#   Stopping...

# %%
# !pip install openai streamlit

# %%
# !npm install localtunnel

# %%
# !streamlit run /content/app_new.py &>/content/logs.txt & npx localtunnel --port 8501 & curl ipv4.icanhazip.com
# Out:
# 35.193.40.251
# npx: installed 22 in 3.941s
# your url is: https://fast-gifts-dance.loca.lt

# %%
# !npx localtunnel --port 8501
# Out:
# npx: installed 22 in 1.942s
# your url is: https://petite-books-sleep.loca.lt
# ^C

# %%
import urllib
print("Password/Enpoint IP for localtunnel is:",urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n"))
# Out:
# Password/Enpoint IP for localtunnel is: 34.126.130.146

# %% [markdown]
# #Integrated with OPENAI api key

# %%
# !pip install openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 kB 2.3 MB/s eta 0:00:00
# ...

# %%
import openai
import requests

# Replace 'YOUR_OPENAI_API_KEY' with your actual API key
openai.api_key = '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'

def generate_ad_tagline(prompt):
    response = openai.Completion.create(
        engine="text-davinci-002",  # You can use a different engine if you prefer
        prompt=prompt,
        max_tokens=50,  # Adjust the number of tokens to control the length of the response
        temperature=0.7,  # Adjust the temperature for more or less randomness
        stop=None  # You can provide a list of stop tokens to control when to end the tagline
    )
    return response.choices[0].text.strip()

# Example usage:
prompt = "Create a catchy tagline for a new energy drink: 'PowerUp'"
tagline = generate_ad_tagline(prompt)
print(tagline)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-5-57d7fed32e68> in <cell line: 19>()
#      17 # Example usage:
#      18 prompt = "Create a catchy tagline for a new energy drink: 'PowerUp'"
# ---> 19 tagline = generate_ad_tagline(prompt)
#      20 print(tagline)
#
# <ipython-input-5-57d7fed32e68> in generate_ad_tagline(prompt)
#       6
#       7 def generate_ad_tagline(prompt):
# ----> 8     response = openai.Completion.create(
#       9         engine="text-davinci-002",  # You can use a different engine if you prefer
#      10         prompt=prompt,
#
# /usr/local/lib/python3.10/dist-packages/openai/api_resources/completion.py in create(cls, *args, **kwargs)
#      23         while True:
#      24             try:
# ---> 25                 return super().create(*args, **kwargs)
#      26             except TryAgain as e:
# ...
